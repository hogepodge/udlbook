# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298995, train error 89.70,  test loss 2.296172, test error 89.75
# Epoch   100, train loss 1.929071, train error 72.55,  test loss 1.769150, test error 70.00
# Epoch   200, train loss 1.924484, train error 72.25,  test loss 1.763030, test error 69.85
# Epoch   300, train loss 1.915416, train error 71.70,  test loss 1.737823, test error 69.12
# Epoch   400, train loss 1.914842, train error 71.20,  test loss 1.740197, test error 68.45
# Epoch   500, train loss 1.914307, train error 71.00,  test loss 1.737823, test error 69.18
# Epoch   600, train loss 1.920481, train error 71.80,  test loss 1.749408, test error 69.78
# Epoch   700, train loss 1.912550, train error 71.75,  test loss 1.737010, test error 69.22
# Epoch   800, train loss 1.915804, train error 71.28,  test loss 1.738552, test error 68.47
# Epoch   900, train loss 1.913421, train error 71.93,  test loss 1.734415, test error 69.90
# Training model with   4 hidden variables
# Epoch     0, train loss 2.272316, train error 89.38,  test loss 2.266438, test error 90.25
# Epoch   100, train loss 1.781308, train error 66.18,  test loss 1.607960, test error 62.92
# Epoch   200, train loss 1.741112, train error 61.97,  test loss 1.525916, test error 58.95
# Epoch   300, train loss 1.727020, train error 62.28,  test loss 1.514490, test error 58.25
# Epoch   400, train loss 1.715346, train error 62.50,  test loss 1.513901, test error 59.05
# Epoch   500, train loss 1.716460, train error 61.85,  test loss 1.520629, test error 59.03
# Epoch   600, train loss 1.711625, train error 62.03,  test loss 1.514662, test error 58.62
# Epoch   700, train loss 1.710174, train error 61.90,  test loss 1.515130, test error 58.70
# Epoch   800, train loss 1.710835, train error 62.97,  test loss 1.518340, test error 59.67
# Epoch   900, train loss 1.713646, train error 61.83,  test loss 1.520767, test error 59.53
# Training model with   6 hidden variables
# Epoch     0, train loss 2.294650, train error 87.32,  test loss 2.289982, test error 86.50
# Epoch   100, train loss 1.724809, train error 60.70,  test loss 1.548187, test error 59.60
# Epoch   200, train loss 1.682956, train error 60.25,  test loss 1.496302, test error 57.85
# Epoch   300, train loss 1.669072, train error 60.25,  test loss 1.494432, test error 57.25
# Epoch   400, train loss 1.652461, train error 60.15,  test loss 1.481093, test error 57.08
# Epoch   500, train loss 1.642948, train error 60.17,  test loss 1.487500, test error 57.55
# Epoch   600, train loss 1.636061, train error 59.28,  test loss 1.477414, test error 56.60
# Epoch   700, train loss 1.628060, train error 58.42,  test loss 1.477278, test error 56.47
# Epoch   800, train loss 1.629326, train error 58.50,  test loss 1.487611, test error 56.28
# Epoch   900, train loss 1.629926, train error 58.08,  test loss 1.478735, test error 56.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.250749, train error 84.53,  test loss 2.247033, test error 83.10
# Epoch   100, train loss 1.643868, train error 58.17,  test loss 1.474087, test error 56.58
# Epoch   200, train loss 1.586446, train error 55.78,  test loss 1.441901, test error 54.85
# Epoch   300, train loss 1.573236, train error 55.25,  test loss 1.439609, test error 54.20
# Epoch   400, train loss 1.555818, train error 55.03,  test loss 1.440915, test error 54.47
# Epoch   500, train loss 1.549681, train error 53.88,  test loss 1.448710, test error 53.97
# Epoch   600, train loss 1.539798, train error 54.20,  test loss 1.447513, test error 54.50
# Epoch   700, train loss 1.530020, train error 53.35,  test loss 1.451092, test error 54.60
# Epoch   800, train loss 1.539716, train error 54.22,  test loss 1.455716, test error 55.20
# Epoch   900, train loss 1.525993, train error 52.85,  test loss 1.460199, test error 54.22
# Training model with  10 hidden variables
# Epoch     0, train loss 2.191454, train error 83.60,  test loss 2.158577, test error 82.07
# Epoch   100, train loss 1.547893, train error 52.28,  test loss 1.398018, test error 51.70
# Epoch   200, train loss 1.494426, train error 50.80,  test loss 1.377323, test error 51.78
# Epoch   300, train loss 1.475996, train error 50.62,  test loss 1.391106, test error 51.67
# Epoch   400, train loss 1.467160, train error 49.70,  test loss 1.401464, test error 51.97
# Epoch   500, train loss 1.457931, train error 49.28,  test loss 1.400312, test error 51.33
# Epoch   600, train loss 1.456263, train error 49.25,  test loss 1.405093, test error 51.83
# Epoch   700, train loss 1.453828, train error 49.58,  test loss 1.400528, test error 51.55
# Epoch   800, train loss 1.451697, train error 49.53,  test loss 1.405543, test error 51.00
# Epoch   900, train loss 1.451608, train error 49.50,  test loss 1.405770, test error 51.50
# Training model with  14 hidden variables
# Epoch     0, train loss 2.256871, train error 84.53,  test loss 2.246224, test error 84.60
# Epoch   100, train loss 1.536686, train error 52.42,  test loss 1.431667, test error 53.90
# Epoch   200, train loss 1.437113, train error 49.83,  test loss 1.403571, test error 53.08
# Epoch   300, train loss 1.409065, train error 48.97,  test loss 1.437189, test error 54.08
# Epoch   400, train loss 1.385885, train error 47.75,  test loss 1.457487, test error 54.50
# Epoch   500, train loss 1.379557, train error 47.38,  test loss 1.492666, test error 54.72
# Epoch   600, train loss 1.363500, train error 47.12,  test loss 1.502775, test error 54.40
# Epoch   700, train loss 1.366078, train error 47.97,  test loss 1.517425, test error 54.03
# Epoch   800, train loss 1.357274, train error 48.00,  test loss 1.527610, test error 54.78
# Epoch   900, train loss 1.350024, train error 47.58,  test loss 1.562937, test error 55.72
# Training model with  18 hidden variables
# Epoch     0, train loss 2.143111, train error 78.93,  test loss 2.094456, test error 78.82
# Epoch   100, train loss 1.372841, train error 45.80,  test loss 1.287325, test error 48.62
# Epoch   200, train loss 1.285092, train error 43.17,  test loss 1.317406, test error 48.92
# Epoch   300, train loss 1.229652, train error 40.95,  test loss 1.353455, test error 49.05
# Epoch   400, train loss 1.203637, train error 41.05,  test loss 1.388766, test error 50.53
# Epoch   500, train loss 1.176807, train error 40.33,  test loss 1.405575, test error 49.95
# Epoch   600, train loss 1.167322, train error 40.45,  test loss 1.428353, test error 50.00
# Epoch   700, train loss 1.154781, train error 40.03,  test loss 1.466383, test error 50.70
# Epoch   800, train loss 1.157323, train error 40.50,  test loss 1.494974, test error 51.58
# Epoch   900, train loss 1.144740, train error 39.83,  test loss 1.506181, test error 51.10
# Training model with  22 hidden variables
# Epoch     0, train loss 2.134246, train error 77.97,  test loss 2.087195, test error 78.15
# Epoch   100, train loss 1.332584, train error 44.62,  test loss 1.389494, test error 51.47
# Epoch   200, train loss 1.198147, train error 39.78,  test loss 1.401954, test error 50.22
# Epoch   300, train loss 1.134190, train error 38.05,  test loss 1.463648, test error 50.20
# Epoch   400, train loss 1.079738, train error 36.45,  test loss 1.541995, test error 51.08
# Epoch   500, train loss 1.052419, train error 36.42,  test loss 1.632945, test error 51.72
# Epoch   600, train loss 1.030341, train error 35.53,  test loss 1.692750, test error 52.65
# Epoch   700, train loss 1.016452, train error 34.82,  test loss 1.752074, test error 53.05
# Epoch   800, train loss 1.013658, train error 34.93,  test loss 1.825362, test error 53.62
# Epoch   900, train loss 1.015181, train error 35.72,  test loss 1.849198, test error 53.50
# Training model with  26 hidden variables
# Epoch     0, train loss 2.210435, train error 81.95,  test loss 2.188308, test error 81.40
# Epoch   100, train loss 1.233733, train error 40.62,  test loss 1.364277, test error 50.83
# Epoch   200, train loss 1.053419, train error 35.35,  test loss 1.486431, test error 51.22
# Epoch   300, train loss 0.993535, train error 34.07,  test loss 1.587005, test error 52.53
# Epoch   400, train loss 0.950989, train error 32.70,  test loss 1.669510, test error 52.65
# Epoch   500, train loss 0.936040, train error 32.03,  test loss 1.733550, test error 53.22
# Epoch   600, train loss 0.918831, train error 31.88,  test loss 1.801374, test error 53.40
# Epoch   700, train loss 0.896470, train error 31.40,  test loss 1.843521, test error 53.83
# Epoch   800, train loss 0.894819, train error 31.57,  test loss 1.927500, test error 54.33
# Epoch   900, train loss 0.881925, train error 30.43,  test loss 2.001759, test error 55.40
# Training model with  30 hidden variables
# Epoch     0, train loss 2.095377, train error 77.18,  test loss 2.029895, test error 76.20
# Epoch   100, train loss 1.148198, train error 37.55,  test loss 1.398770, test error 51.97
# Epoch   200, train loss 0.996251, train error 33.50,  test loss 1.571860, test error 53.40
# Epoch   300, train loss 0.902483, train error 29.80,  test loss 1.743776, test error 54.60
# Epoch   400, train loss 0.848633, train error 27.57,  test loss 1.875157, test error 54.50
# Epoch   500, train loss 0.808595, train error 26.22,  test loss 2.110627, test error 57.35
# Epoch   600, train loss 0.781274, train error 25.82,  test loss 2.266840, test error 57.42
# Epoch   700, train loss 0.757041, train error 25.78,  test loss 2.369187, test error 57.10
# Epoch   800, train loss 0.725492, train error 25.60,  test loss 2.510458, test error 57.60
# Epoch   900, train loss 0.752641, train error 26.88,  test loss 2.634605, test error 58.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.141111, train error 79.53,  test loss 2.105169, test error 79.85
# Epoch   100, train loss 1.084518, train error 35.00,  test loss 1.362651, test error 49.38
# Epoch   200, train loss 0.865693, train error 28.12,  test loss 1.643317, test error 52.28
# Epoch   300, train loss 0.713155, train error 23.25,  test loss 1.949289, test error 54.28
# Epoch   400, train loss 0.656714, train error 21.88,  test loss 2.264696, test error 55.62
# Epoch   500, train loss 0.593821, train error 20.18,  test loss 2.575184, test error 56.17
# Epoch   600, train loss 0.574625, train error 19.38,  test loss 2.874585, test error 57.20
# Epoch   700, train loss 0.551712, train error 19.32,  test loss 3.164837, test error 58.75
# Epoch   800, train loss 0.504450, train error 17.47,  test loss 3.458040, test error 58.92
# Epoch   900, train loss 0.480968, train error 16.47,  test loss 3.702499, test error 59.33
# Training model with  40 hidden variables
# Epoch     0, train loss 2.145709, train error 79.43,  test loss 2.103475, test error 78.85
# Epoch   100, train loss 0.900260, train error 29.20,  test loss 1.487272, test error 50.72
# Epoch   200, train loss 0.630808, train error 20.85,  test loss 2.068648, test error 53.62
# Epoch   300, train loss 0.504686, train error 16.43,  test loss 2.716400, test error 54.72
# Epoch   400, train loss 0.399715, train error 13.47,  test loss 3.318197, test error 55.88
# Epoch   500, train loss 0.405050, train error 13.65,  test loss 3.952108, test error 56.60
# Epoch   600, train loss 0.329088, train error 11.47,  test loss 4.484125, test error 57.12
# Epoch   700, train loss 0.274164, train error 9.18,  test loss 5.016446, test error 56.50
# Epoch   800, train loss 0.317103, train error 11.07,  test loss 5.712874, test error 57.12
# Epoch   900, train loss 0.332042, train error 11.90,  test loss 6.322320, test error 58.05
# Training model with  45 hidden variables
# Epoch     0, train loss 2.128531, train error 80.30,  test loss 2.079439, test error 77.60
# Epoch   100, train loss 0.830918, train error 26.70,  test loss 1.566647, test error 52.20
# Epoch   200, train loss 0.505127, train error 15.38,  test loss 2.274369, test error 53.70
# Epoch   300, train loss 0.363519, train error 12.07,  test loss 3.332511, test error 55.33
# Epoch   400, train loss 0.225664, train error 6.55,  test loss 4.450173, test error 55.33
# Epoch   500, train loss 0.224705, train error 8.07,  test loss 5.727397, test error 56.40
# Epoch   600, train loss 0.214046, train error 7.85,  test loss 6.878687, test error 56.92
# Epoch   700, train loss 0.210394, train error 7.47,  test loss 7.933384, test error 55.90
# Epoch   800, train loss 0.013080, train error 0.00,  test loss 8.911057, test error 56.50
# Epoch   900, train loss 0.008267, train error 0.00,  test loss 9.633679, test error 56.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.108373, train error 77.28,  test loss 2.055052, test error 77.10
# Epoch   100, train loss 0.749331, train error 23.55,  test loss 1.552997, test error 50.17
# Epoch   200, train loss 0.373747, train error 12.25,  test loss 2.591748, test error 53.75
# Epoch   300, train loss 0.159093, train error 4.12,  test loss 4.162294, test error 54.33
# Epoch   400, train loss 0.039971, train error 0.15,  test loss 5.860796, test error 54.88
# Epoch   500, train loss 0.013050, train error 0.00,  test loss 6.945686, test error 55.42
# Epoch   600, train loss 0.008473, train error 0.00,  test loss 7.641179, test error 55.55
# Epoch   700, train loss 0.005962, train error 0.00,  test loss 8.134074, test error 55.75
# Epoch   800, train loss 0.004600, train error 0.00,  test loss 8.532870, test error 55.70
# Epoch   900, train loss 0.003697, train error 0.00,  test loss 8.868031, test error 55.83
# Training model with  55 hidden variables
# Epoch     0, train loss 2.087940, train error 76.62,  test loss 2.050659, test error 76.60
# Epoch   100, train loss 0.652862, train error 20.07,  test loss 1.684253, test error 51.72
# Epoch   200, train loss 0.249193, train error 7.05,  test loss 3.162428, test error 55.30
# Epoch   300, train loss 0.037126, train error 0.05,  test loss 5.007697, test error 54.67
# Epoch   400, train loss 0.013806, train error 0.00,  test loss 6.075236, test error 55.12
# Epoch   500, train loss 0.008154, train error 0.00,  test loss 6.732976, test error 55.20
# Epoch   600, train loss 0.005634, train error 0.00,  test loss 7.197814, test error 55.47
# Epoch   700, train loss 0.004250, train error 0.00,  test loss 7.556771, test error 55.45
# Epoch   800, train loss 0.003388, train error 0.00,  test loss 7.851836, test error 55.33
# Epoch   900, train loss 0.002780, train error 0.00,  test loss 8.108813, test error 55.55
# Training model with  60 hidden variables
# Epoch     0, train loss 2.084060, train error 77.35,  test loss 2.034001, test error 76.12
# Epoch   100, train loss 0.521568, train error 14.62,  test loss 1.834360, test error 52.67
# Epoch   200, train loss 0.117191, train error 1.62,  test loss 3.630250, test error 55.75
# Epoch   300, train loss 0.019355, train error 0.00,  test loss 5.080412, test error 56.08
# Epoch   400, train loss 0.009312, train error 0.00,  test loss 5.804430, test error 55.78
# Epoch   500, train loss 0.005873, train error 0.00,  test loss 6.288465, test error 55.80
# Epoch   600, train loss 0.004179, train error 0.00,  test loss 6.644471, test error 55.92
# Epoch   700, train loss 0.003216, train error 0.00,  test loss 6.929350, test error 56.08
# Epoch   800, train loss 0.002581, train error 0.00,  test loss 7.159619, test error 56.03
# Epoch   900, train loss 0.002145, train error 0.00,  test loss 7.358627, test error 56.15
# Training model with  70 hidden variables
# Epoch     0, train loss 2.079084, train error 76.45,  test loss 2.021962, test error 75.93
# Epoch   100, train loss 0.423633, train error 11.50,  test loss 1.991237, test error 53.62
# Epoch   200, train loss 0.036354, train error 0.00,  test loss 3.624871, test error 54.97
# Epoch   300, train loss 0.011640, train error 0.00,  test loss 4.425956, test error 55.05
# Epoch   400, train loss 0.006522, train error 0.00,  test loss 4.879449, test error 55.17
# Epoch   500, train loss 0.004311, train error 0.00,  test loss 5.198302, test error 55.45
# Epoch   600, train loss 0.003182, train error 0.00,  test loss 5.438686, test error 55.47
# Epoch   700, train loss 0.002493, train error 0.00,  test loss 5.635415, test error 55.60
# Epoch   800, train loss 0.002035, train error 0.00,  test loss 5.796745, test error 55.55
# Epoch   900, train loss 0.001708, train error 0.00,  test loss 5.936428, test error 55.67
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024358, train error 74.75,  test loss 1.943072, test error 74.03
# Epoch   100, train loss 0.235832, train error 4.47,  test loss 2.102439, test error 51.53
# Epoch   200, train loss 0.020288, train error 0.00,  test loss 3.469229, test error 52.62
# Epoch   300, train loss 0.008074, train error 0.00,  test loss 4.036653, test error 53.10
# Epoch   400, train loss 0.004753, train error 0.00,  test loss 4.366801, test error 53.08
# Epoch   500, train loss 0.003278, train error 0.00,  test loss 4.603864, test error 53.38
# Epoch   600, train loss 0.002467, train error 0.00,  test loss 4.785125, test error 53.45
# Epoch   700, train loss 0.001955, train error 0.00,  test loss 4.935786, test error 53.35
# Epoch   800, train loss 0.001609, train error 0.00,  test loss 5.061324, test error 53.40
# Epoch   900, train loss 0.001360, train error 0.00,  test loss 5.171355, test error 53.25
# Training model with  90 hidden variables
# Epoch     0, train loss 2.006749, train error 74.43,  test loss 1.926130, test error 74.80
# Epoch   100, train loss 0.149601, train error 1.75,  test loss 2.331042, test error 53.12
# Epoch   200, train loss 0.014545, train error 0.00,  test loss 3.414539, test error 53.42
# Epoch   300, train loss 0.006403, train error 0.00,  test loss 3.854417, test error 53.42
# Epoch   400, train loss 0.003917, train error 0.00,  test loss 4.128603, test error 53.17
# Epoch   500, train loss 0.002758, train error 0.00,  test loss 4.327448, test error 53.15
# Epoch   600, train loss 0.002100, train error 0.00,  test loss 4.479037, test error 53.15
# Epoch   700, train loss 0.001680, train error 0.00,  test loss 4.606957, test error 53.28
# Epoch   800, train loss 0.001392, train error 0.00,  test loss 4.714509, test error 53.42
# Epoch   900, train loss 0.001182, train error 0.00,  test loss 4.807466, test error 53.42
# Training model with 100 hidden variables
# Epoch     0, train loss 2.028924, train error 75.22,  test loss 1.974060, test error 76.15
# Epoch   100, train loss 0.105238, train error 0.18,  test loss 2.372709, test error 52.17
# Epoch   200, train loss 0.012834, train error 0.00,  test loss 3.333935, test error 52.50
# Epoch   300, train loss 0.005884, train error 0.00,  test loss 3.733361, test error 52.03
# Epoch   400, train loss 0.003658, train error 0.00,  test loss 3.988166, test error 52.17
# Epoch   500, train loss 0.002593, train error 0.00,  test loss 4.170459, test error 52.22
# Epoch   600, train loss 0.001982, train error 0.00,  test loss 4.316093, test error 52.08
# Epoch   700, train loss 0.001590, train error 0.00,  test loss 4.433387, test error 52.17
# Epoch   800, train loss 0.001320, train error 0.00,  test loss 4.532971, test error 52.15
# Epoch   900, train loss 0.001123, train error 0.00,  test loss 4.619868, test error 52.20
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980849, train error 72.22,  test loss 1.899773, test error 71.88
# Epoch   100, train loss 0.049629, train error 0.00,  test loss 2.316616, test error 52.15
# Epoch   200, train loss 0.009438, train error 0.00,  test loss 2.970995, test error 52.15
# Epoch   300, train loss 0.004662, train error 0.00,  test loss 3.254388, test error 52.05
# Epoch   400, train loss 0.002984, train error 0.00,  test loss 3.438937, test error 51.90
# Epoch   500, train loss 0.002154, train error 0.00,  test loss 3.577606, test error 51.92
# Epoch   600, train loss 0.001668, train error 0.00,  test loss 3.685441, test error 51.90
# Epoch   700, train loss 0.001349, train error 0.00,  test loss 3.775392, test error 51.95
# Epoch   800, train loss 0.001126, train error 0.00,  test loss 3.852451, test error 51.90
# Epoch   900, train loss 0.000962, train error 0.00,  test loss 3.918732, test error 51.92
# Training model with 140 hidden variables
# Epoch     0, train loss 1.969061, train error 72.65,  test loss 1.891862, test error 73.40
# Epoch   100, train loss 0.036798, train error 0.00,  test loss 2.149776, test error 49.08
# Epoch   200, train loss 0.008041, train error 0.00,  test loss 2.628617, test error 48.92
# Epoch   300, train loss 0.004126, train error 0.00,  test loss 2.853429, test error 49.12
# Epoch   400, train loss 0.002678, train error 0.00,  test loss 3.003252, test error 49.20
# Epoch   500, train loss 0.001946, train error 0.00,  test loss 3.114260, test error 49.05
# Epoch   600, train loss 0.001513, train error 0.00,  test loss 3.202000, test error 48.95
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.275608, test error 49.08
# Epoch   800, train loss 0.001029, train error 0.00,  test loss 3.338557, test error 49.15
# Epoch   900, train loss 0.000882, train error 0.00,  test loss 3.393362, test error 49.08
# Training model with 160 hidden variables
# Epoch     0, train loss 1.974142, train error 71.57,  test loss 1.905347, test error 73.18
# Epoch   100, train loss 0.028863, train error 0.00,  test loss 2.166754, test error 49.60
# Epoch   200, train loss 0.007227, train error 0.00,  test loss 2.595377, test error 50.08
# Epoch   300, train loss 0.003801, train error 0.00,  test loss 2.806479, test error 50.33
# Epoch   400, train loss 0.002498, train error 0.00,  test loss 2.945601, test error 50.10
# Epoch   500, train loss 0.001829, train error 0.00,  test loss 3.049179, test error 50.08
# Epoch   600, train loss 0.001429, train error 0.00,  test loss 3.132280, test error 50.00
# Epoch   700, train loss 0.001163, train error 0.00,  test loss 3.201084, test error 49.95
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.260479, test error 49.88
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.311318, test error 49.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.941052, train error 72.15,  test loss 1.844221, test error 72.20
# Epoch   100, train loss 0.025311, train error 0.00,  test loss 2.058443, test error 48.55
# Epoch   200, train loss 0.006722, train error 0.00,  test loss 2.419066, test error 48.35
# Epoch   300, train loss 0.003583, train error 0.00,  test loss 2.602798, test error 48.65
# Epoch   400, train loss 0.002369, train error 0.00,  test loss 2.724225, test error 48.65
# Epoch   500, train loss 0.001742, train error 0.00,  test loss 2.817568, test error 48.58
# Epoch   600, train loss 0.001364, train error 0.00,  test loss 2.892004, test error 48.55
# Epoch   700, train loss 0.001113, train error 0.00,  test loss 2.953578, test error 48.60
# Epoch   800, train loss 0.000936, train error 0.00,  test loss 3.006238, test error 48.60
# Epoch   900, train loss 0.000804, train error 0.00,  test loss 3.053245, test error 48.62
# Training model with 200 hidden variables
# Epoch     0, train loss 1.934202, train error 71.40,  test loss 1.852866, test error 73.00
# Epoch   100, train loss 0.021508, train error 0.00,  test loss 2.053221, test error 48.10
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.376742, test error 47.88
# Epoch   300, train loss 0.003307, train error 0.00,  test loss 2.543766, test error 47.97
# Epoch   400, train loss 0.002206, train error 0.00,  test loss 2.654031, test error 47.80
# Epoch   500, train loss 0.001629, train error 0.00,  test loss 2.738474, test error 47.80
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.805765, test error 47.83
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.862063, test error 47.72
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.910895, test error 47.72
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.953286, test error 47.67
# Training model with 250 hidden variables
# Epoch     0, train loss 1.909681, train error 69.65,  test loss 1.840149, test error 70.15
# Epoch   100, train loss 0.016941, train error 0.00,  test loss 2.033819, test error 50.12
# Epoch   200, train loss 0.005340, train error 0.00,  test loss 2.304220, test error 49.88
# Epoch   300, train loss 0.002985, train error 0.00,  test loss 2.447236, test error 50.10
# Epoch   400, train loss 0.002018, train error 0.00,  test loss 2.545669, test error 49.97
# Epoch   500, train loss 0.001504, train error 0.00,  test loss 2.620139, test error 49.92
# Epoch   600, train loss 0.001187, train error 0.00,  test loss 2.680200, test error 49.88
# Epoch   700, train loss 0.000975, train error 0.00,  test loss 2.729748, test error 49.88
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.772713, test error 49.90
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.810584, test error 49.85
# Training model with 300 hidden variables
# Epoch     0, train loss 1.887012, train error 68.00,  test loss 1.814738, test error 70.72
# Epoch   100, train loss 0.014193, train error 0.00,  test loss 1.904421, test error 47.03
# Epoch   200, train loss 0.004753, train error 0.00,  test loss 2.124863, test error 46.62
# Epoch   300, train loss 0.002697, train error 0.00,  test loss 2.247928, test error 46.70
# Epoch   400, train loss 0.001839, train error 0.00,  test loss 2.333441, test error 46.55
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.397890, test error 46.60
# Epoch   600, train loss 0.001091, train error 0.00,  test loss 2.450197, test error 46.62
# Epoch   700, train loss 0.000898, train error 0.00,  test loss 2.494600, test error 46.60
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.531997, test error 46.65
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.565816, test error 46.62
# Training model with 400 hidden variables
# Epoch     0, train loss 1.911919, train error 68.40,  test loss 1.846772, test error 71.05
# Epoch   100, train loss 0.011755, train error 0.00,  test loss 1.809837, test error 47.03
# Epoch   200, train loss 0.004184, train error 0.00,  test loss 1.998762, test error 46.95
# Epoch   300, train loss 0.002425, train error 0.00,  test loss 2.099130, test error 47.12
# Epoch   400, train loss 0.001671, train error 0.00,  test loss 2.169174, test error 47.22
# Epoch   500, train loss 0.001260, train error 0.00,  test loss 2.222802, test error 47.20
# Epoch   600, train loss 0.001003, train error 0.00,  test loss 2.266789, test error 47.12
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.303391, test error 47.20
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.335153, test error 47.08
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.362897, test error 46.95

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
